# %% [markdown]
# <a href="https://colab.research.google.com/github/akshayxemo/data-science-lab/blob/main/Salary_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Salaray prediction of employees based on the year of experience using linear regression.

# %% [markdown]
# 1.   visualize the original data point along with the regression line
#      using scatter plot
# 2.   Determine the model's performance using metric like r2

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
# from google.colab import drive
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# drive.mount('/content/drive')

# %%
# data = pd.read_csv('/content/sample_data/Salary.csv')
data = pd.read_csv('SalaryDataset.csv')
data = data.dropna()
data
# Out:
#       Age  Gender Education Level                      Job Title
# 0    32.0    Male      Bachelor's              Software Engineer  \
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
X = data[['Age', 'Years of Experience']]
y = data['Salary']

# %%
x_scaler = StandardScaler().fit_transform(X)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaler, y, test_size=0.3, random_state=78)

# %%
model = LinearRegression().fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
sn.regplot(x = data['Years of Experience'], y = data['Salary'],  ci = None, data = X)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Salary'>

# %%
R2_score = r2_score(y_pred, y_test)
R2_score * 100
# Out:
# 85.80281852939129

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 268837461.31028277

# %%
sn.regplot(x=y_test, y=y_pred, ci=None, data=X)
# Out:
# <Axes: xlabel='Salary'>

# %% [markdown]
# #Actual Vs Predicted

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(x = x_test[:, 1], y = y_test,  c = 'black')
plt.subplot(1, 2, 2)
plt.scatter(x = x_test[:, 1], y = y_pred,  c = 'blue')
plt.show()
